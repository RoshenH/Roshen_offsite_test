# %%
import re

def secondquestion(input_str):
    x=input_str.split("0")
    while '' in x:
        x.remove('')
    output = {"first name": x[0], "last name": x[1], "id": x[2]}
    
    return output

a= str(input('enter a string\n'))
print(secondquestion(a))
# Out:
# {'first name': 'Robert', 'last name': 'Smith', 'id': '123'}

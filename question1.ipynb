# %%
import datetime

def calander(a,b):
    x=datetime.date(a,b,13)
    a=x.strftime("%a")
    if a == "Fri":
        return True
    else:
        return False

while True:
    a = int(input("Enter your year: "))
    
    if len(str(a))<5:
        
            b= int(input("Enter your month: "))
            while True:
                if b<30:
                    break
            else:
                print("Incorrect month, try again.")
    break
else:
    print("Incorrect year, try again.")



print(calander(a,b))
# Out:
# False
